# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data= pd.read_csv(r'Dataset/WA_Fn-UseC_-Telco-Customer-Churn-selected-columns.csv')

# %%
data=data.copy()

# %%
data.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1733    Male              0      No         No       1          Yes
# 3005  Female              1      No         No      24          Yes
# 5064    Male              0      No         No       2           No
# 5918    Male              0     Yes        Yes      59          Yes
# 6487  Female              0     Yes         No      61          Yes
#
#      InternetService       OnlineSecurity     DeviceProtection  \
# 1733              No  No internet service  No internet service
# 3005              No  No internet service  No internet service
# 5064             DSL                   No                  Yes
# 5918              No  No internet service  No internet service
# 6487     Fiber optic                   No                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 1733  No internet service  No internet service  Month-to-month
# 3005  No internet service  No internet service  Month-to-month
# 5064                   No                   No  Month-to-month
# 5918  No internet service  No internet service        Two year
# 6487                   No                  Yes        Two year
#
#                   PaymentMethod Churn
# 1733               Mailed check    No
# 3005               Mailed check    No
# 5064    Credit card (automatic)   Yes
# 5918               Mailed check    No
# 6487  Bank transfer (automatic)    No

# %%
data['Contract'].value_counts(), data['Partner'].value_counts(), data['InternetService'].value_counts()
# Out:
# (Contract
#  Month-to-month    3875
#  Two year          1695
#  One year          1473
#  Name: count, dtype: int64,
#  Partner
#  No     3641
#  Yes    3402
#  Name: count, dtype: int64,
#  InternetService
#  Fiber optic    3096
#  DSL            2421
#  No             1526
#  Name: count, dtype: int64)

# %%
data.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4030  Female              0      No        Yes       5          Yes
# 5842  Female              0      No         No      13          Yes
# 1253  Female              0      No         No       7          Yes
# 582   Female              1      No         No       4          Yes
# 5195    Male              0      No         No      72          Yes
#
#      InternetService OnlineSecurity DeviceProtection StreamingTV  \
# 4030             DSL             No               No          No
# 5842             DSL            Yes              Yes         Yes
# 1253     Fiber optic             No               No          No
# 582      Fiber optic             No              Yes         Yes
# 5195             DSL            Yes              Yes         Yes
#
#      StreamingMovies        Contract              PaymentMethod Churn
# 4030              No  Month-to-month               Mailed check    No
# 5842             Yes  Month-to-month           Electronic check    No
# 1253             Yes  Month-to-month           Electronic check   Yes
# 582               No  Month-to-month           Electronic check   Yes
# 5195              No        Two year  Bank transfer (automatic)    No

# %%
data[['OnlineSecurity','DeviceProtection','StreamingTV','StreamingMovies']]=data[['OnlineSecurity','DeviceProtection','StreamingTV','StreamingMovies']].replace('No internet service','No')

# %%
sns.histplot(data['tenure'])
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %% [raw]
# One-hot encoding:['gender','SeniorCitizen','Partner','Dependents','PhoneService','InternetService','OnlineSecurity','DeviceProtection','StreamingTV','StreamingMovies','Contract','PaymentMethod']
#
# Label Encoding:
# ['Churn']
#
# Qualtile Transformation:
# ['tenure']

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test= train_test_split(data.drop('Churn', axis=1), data['Churn'], test_size=0.2, random_state=0)

# %%
trnf1= ColumnTransformer([('one-hot', OneHotEncoder(drop='first'), list(range(0,4))+list(range(5,13))), ('power', PowerTransformer(method='yeo-johnson'), [4])], remainder='passthrough')

# %%
x_train.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'InternetService', 'OnlineSecurity', 'DeviceProtection',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaymentMethod'],
#       dtype='str')

# %%
le= LabelEncoder()

y_train_trns= le.fit_transform(y_train)
y_test_trns= le.transform(y_test)

# %%
trnf2= LogisticRegression(max_iter=2000)

# %%
pipe=make_pipeline(trnf1, trnf2)

# %%
from sklearn.model_selection import cross_val_score

# %%
for scoring in ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']:
    scores = cross_val_score(
        pipe,
        x_train,
        y_train_trns,
        cv=5,
        scoring=scoring
    )
    print(scoring, scores.mean())
# Out:
# accuracy 0.8008546873842596
# precision 0.6567390192046537
# recall 0.5309922480620155
# f1 0.5864870948557895
# roc_auc 0.8502160578286752

# %%
pipe.fit(x_train, y_train_trns)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one-hot',
#                                                   OneHotEncoder(drop='first'),
#                                                   [0, 1, 2, 3, 5, 6, 7, 8, 9,
#                                                    10, 11, 12]),
#                                                  ('power', PowerTransformer(),
#                                                   [4])])),
#                 ('logisticregression', LogisticRegression(max_iter=2000))])

# %%
score= cross_val_score(pipe, x_train, y_train_trns, cv=5, scoring='accuracy')
score.mean()
# Out:
# np.float64(0.8008546873842596)

# %%
import joblib

# %%
joblib.dump(pipe,'model_pipeline.pkl')
# Out:
# ['model_pipeline.pkl']

# %%
data['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
data['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
